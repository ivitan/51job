# %%
import pandas as pd
df = pd.read_csv('jobs.csv',encoding='utf-8')
df.head()
# Out:
#                    name    city peops experience      salary education  \
# 0              linux工程师  广州-黄埔区   若干人      无工作经验      6-8千/月      暂无信息
# 1          linux驱动开发工程师      广州    2人     2年工作经验    1-1.2万/月        大专
# 2  Linux运维工程师（有互联网经验优先）  广州-天河区    1人   5-7年工作经验    1-1.5万/月        大专
# 3          Linux C++工程师      广州    2人   3-4年工作经验  1.5-2.5万/月        本科
# 4      Linux系统研发工程师（广州）  广州-天河区   若干人        无要求  0.8-1.6万/月        本科
#
#           company                             com_info  \
# 0      广州登高科技有限公司  民营公司| 150-500人| 电子技术/半导体/集成电路 计算机软件
# 1   广州天嵌计算机科技有限公司   民营公司| 50-150人| 计算机软件 电子技术/半导体/集成电路
# 2  广东中建普联科技股份有限公司       民营公司| 150-500人| 计算机软件 互联网/电子商务
# 3    广东创能科技股份有限公司       民营公司| 150-500人| 互联网/电子商务 计算机软件
# 4        中标软件有限公司                 国企| 500-1000人| 计算机软件
#
#                                             jpb_info
# 0  【岗位职责】：1. 负责无线路由器设备底层开发;2. 负责解决路由器平台在Linux内核方面...
# 1  岗位职责1.从事ARM嵌入式产品Linux/Android BSP移植开发及驱动开发调试工作...
# 2  岗位职责：1、负责服务器、数据库(mysqlsqlserveroracle)的安装配置管理；...
# 3  岗位职责：1.负责软件项目C++部分的开发、测试和维护工作；2.软件产品相关技术文档的编写和...
# 4  岗位职责：负责Linux服务器操作系统、内核驱动、移动终端、定制业务领域的研发工作。任职资格...

# %%
#查看df各列数据类型
df.dtypes
# Out:
# name          object
# city          object
# peops         object
# experience    object
# salary        object
# education     object
# company       object
# com_info      object
# jpb_info      object
# dtype: object

# %%
#对df各非字符串列进行描述性统计（计数，均值，标准差，最大最小，4分位等）
df.describe()
# Out:
#              name    city peops experience    salary education  \
# count        7049    7049  7049       7049      7049      7049
# unique       3651     107    27          8       403         9
# top     Java开发工程师  广州-天河区    1人   3-4年工作经验  1-1.5万/月        本科
# freq          285    2458  2656       1958       802      3652
#
#                company              com_info  \
# count             7049                  7049
# unique            2831                  1291
# top     汇丰软件开发（广东）有限公司  民营公司| 50-150人| 计算机软件
# freq               105                   223
#
#                                                  jpb_info
# count                                                7049
# unique                                               6691
# top     1. 参与应用系统数据库架构规划和设计提供数据库规范指引、性能优化建议等相关工作；2. 负责...
# freq                                                   16

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7049 entries, 0 to 7048
# Data columns (total 9 columns):
# name          7049 non-null object
# city          7049 non-null object
# peops         7049 non-null object
# experience    7049 non-null object
# salary        7049 non-null object
# education     7049 non-null object
# company       7049 non-null object
# com_info      7049 non-null object
# jpb_info      7049 non-null object
# dtypes: object(9)
# memory usage: 495.7+ KB

# %% [markdown]
# # 缺失值重复值

# %%
#对数据框各列分别进行判断，返回每列是否有缺失值
df.isnull().any()
# Out:
# name          False
# city          False
# peops         False
# experience    False
# salary        False
# education     False
# company       False
# com_info      False
# jpb_info      False
# dtype: bool

# %%
# 统计数据框空值
df.isnull().sum()
# Out:
# name          0
# city          0
# peops         0
# experience    0
# salary        0
# education     0
# company       0
# com_info      0
# jpb_info      0
# dtype: int64

# %%
#删除df具有Nan值的行
df.dropna()
#删除df所有列均为空值的行记录
df.dropna(how='all')
# Out:
#                               name    city peops experience      salary  \
# 0                         linux工程师  广州-黄埔区   若干人      无工作经验      6-8千/月
# 1                     linux驱动开发工程师      广州    2人     2年工作经验    1-1.2万/月
# 2             Linux运维工程师（有互联网经验优先）  广州-天河区    1人   5-7年工作经验    1-1.5万/月
# 3                     Linux C++工程师      广州    2人   3-4年工作经验  1.5-2.5万/月
# 4                 Linux系统研发工程师（广州）  广州-天河区   若干人        无要求  0.8-1.6万/月
# 5                       Linux运维工程师  广州-天河区    2人     2年工作经验    0.6-1万/月
# 6                    嵌入式Linux软件工程师  广州-黄埔区    1人   3-4年工作经验  0.8-1.1万/月
# 7                       Linux运维工程师      广州    3人     1年工作经验    0.8-1万/月
# 8         C++ / 嵌入式Linux / QT开发工程师  广州-海珠区   若干人      无工作经验      250元/天
# 9                Linux嵌入式软件QT开发工程师  广州-番禺区    2人     2年工作经验  0.6-1.5万/月
# 10               软件工程师（RTOS/Linux）      广州   若干人        无要求        暂无信息
# 11                       linux软件开发  广州-天河区    2人        无要求      1-3万/月
# 12                    Linux嵌入开发工程师  广州-番禺区    2人     1年工作经验  0.6-1.5万/月
# 13             Linux C软件研发工程师（BNG）  广州-天河区   若干人        无要求      1-2万/月
# 14    TV 研发工程师-LINUX方向(000443)（广州）      广州    2人        无要求        暂无信息
# 15                    Linux系统软件工程师      广州    1人     2年工作经验  1.4-1.7万/月
# 16                      Linux驱动工程师  广州-黄埔区    2人        无要求    0.8-2万/月
# 17                      Linux运维工程师  广州-黄埔区    3人        无要求      6-8千/月
# 18            项目经理（云平台Linux）（南方电网）  广州-天河区   若干人   5-7年工作经验      1-2万/月
# 19                  高级linux软件开发工程师  广州-天河区    1人   3-4年工作经验  1.2-1.8万/月
# 20              软件工程师（Linux系统 C语言）  广州-南沙区   若干人      无工作经验  0.6-1.2万/月
# 21               C++中级软件工程师（Linux）  广州-黄埔区    1人     1年工作经验    5-7.5千/月
# 22                   嵌入式linux开发工程师  广州-黄埔区    1人        无要求  1.5-2.5万/月
# 23                      Linux运维工程师  广州-天河区    3人   5-7年工作经验    1-1.5万/月
# 24                      Linux运维工程师  北京-海淀区    2人     2年工作经验     8-10万/年
# 25                      Linux运维工程师  广州-天河区   若干人     2年工作经验    1-1.2万/月
# 26                    软件工程师（Linux）  广州-天河区    1人     2年工作经验  0.8-1.2万/月
# 27                 嵌入式Linux软件开发工程师  广州-黄埔区    2人     2年工作经验    1-1.5万/月
# 28                    Linux系统运维工程师      广州   若干人   3-4年工作经验  0.8-1.2万/月
# 29                 系统运维工程师/linux运维      广州    1人     2年工作经验      5-8千/月
# ...                            ...     ...   ...        ...         ...
# 7019                 嵌入式Linux开发工程师      东莞    2人     2年工作经验  0.8-2.5万/月
# 7020          软件研发工程师（C/C++、linux）      广州    5人     1年工作经验    12-24万/年
# 7021                    Linux开发工程师  广州-白云区    5人     2年工作经验    1-1.8万/月
# 7022                    Linux开发工程师      东莞    1人   3-4年工作经验    1-1.5万/月
# 7023                Linux C++高级工程师  深圳-福田区    2人   5-7年工作经验    1.5-3万/月
# 7024                  linux C系统架构师      广州    2人        无要求    1.5-2万/月
# 7025                  linux运维工程师初级  广州-越秀区    1人     2年工作经验      6-8千/月
# 7026                    Linux开发工程师  广州-天河区   若干人   5-7年工作经验    25-35万/年
# 7027                Linux嵌入式C++工程师  广州-白云区    1人     1年工作经验  0.8-1.3万/月
# 7028                广州移动LINUX运维工程师  广州-海珠区    1人     2年工作经验      5-8千/月
# 7029                    Linux开发工程师     广东省   若干人   3-4年工作经验  0.6-1.2万/月
# 7030                 嵌入式Linux软件工程师  广州-黄埔区    2人   3-4年工作经验  1.3-2.5万/月
# 7031               嵌入式linux系统开发工程师  广州-天河区    1人     2年工作经验  0.8-1.5万/月
# 7032                 Linux嵌入式软件工程师  广州-番禺区    1人   3-4年工作经验    0.8-1万/月
# 7033                    Linux服务器开发  广州-天河区    1人        无要求  0.8-1.6万/月
# 7034                    Linux运维工程师  广州-花都区    1人     2年工作经验    1-1.5万/月
# 7035                  高级Linux实施工程师      广州   若干人   3-4年工作经验    1.5-3万/月
# 7036                    高级Linux工程师  广州-天河区    5人   3-4年工作经验  0.8-1.7万/月
# 7037                    Linux运维工程师  广州-番禺区    1人     2年工作经验    1-1.8万/月
# 7038                  Linux开发运维工程师      广州   10人   3-4年工作经验  0.8-1.5万/月
# 7039                    Linux开发工程师      广州    3人        无要求  0.7-1.6万/月
# 7040                    Linux运维工程师  广州-天河区    1人     2年工作经验    0.8-1万/月
# 7041                Linux C软件开发工程师  广州-黄埔区    2人        无要求  0.6-1.5万/月
# 7042                Linux C++开发工程师  广州-黄埔区    1人   5-7年工作经验  0.8-1.6万/月
# 7043                    Linux开发工程师  广州-番禺区    2人     2年工作经验  0.8-1.5万/月
# 7044                    Linux运维工程师      广州   若干人        无要求    0.8-1万/月
# 7045                 Linux音视频开发工程师  广州-白云区    2人     1年工作经验  0.6-1.5万/月
# 7046        linux C/C++开发工程师（图像方向）  广州-黄埔区   若干人     1年工作经验  1.2-1.8万/月
# 7047                    Linux研发工程师  广州-黄埔区    2人     2年工作经验    0.8-2万/月
# 7048                 嵌入式linux开发工程师  广州-黄埔区    1人   5-7年工作经验    1-1.8万/月
#
#      education              company  \
# 0         暂无信息           广州登高科技有限公司
# 1           大专        广州天嵌计算机科技有限公司
# 2           大专       广东中建普联科技股份有限公司
# 3           本科         广东创能科技股份有限公司
# 4           本科             中标软件有限公司
# 5           大专           广东丰德科技有限公司
# 6         暂无信息         广州敦和信息技术有限公司
# 7           本科     联合永道（上海）信息技术有限公司
# 8           本科         广州智讯通信系统有限公司
# 9           本科        广州市世腾电子科技有限公司
# 10          本科      安凯（广州）微电子技术有限公司
# 11          本科         广州驰凯电子科技有限公司
# 12          本科          广州市技美机床有限公司
# 13          本科         广州凯媒通讯技术有限公司
# 14          本科              软件与服务中心
# 15          大专         广州路派电子科技有限公司
# 16        暂无信息         广东优库智联控股有限公司
# 17        暂无信息       广州市埃特斯通讯设备有限公司
# 18          本科         广州腾宇电力科技有限公司
# 19          本科         广州魅视电子科技有限公司
# 20          本科         通则康威智能科技有限公司
# 21          中专     珠海珠保金鹏安全技术服务有限公司
# 22          本科         北京华亘安邦科技有限公司
# 23          本科        广州市微柏软件股份有限公司
# 24          大专         北京神州立诚科技有限公司
# 25          大专        小高德（广州）置业有限公司
# 26          本科         广州立功科技股份有限公司
# 27          本科        浙江亿玮新能源科技有限公司
# 28          大专     上海新炬网络信息技术股份有限公司
# 29          本科                小i机器人
# ...        ...                  ...
# 7019        大专         东莞昆盈电脑制品有限公司
# 7020        本科       广州市奥威亚电子科技有限公司
# 7021        大专              迪士普研发中心
# 7022        本科          易事特集团股份有限公司
# 7023        本科         农创品牌运营股份有限公司
# 7024        本科       蓝盾信息安全技术股份有限公司
# 7025        本科         圣旺科技（广州）有限公司
# 7026        本科        广州新航行系统技术有限公司
# 7027        本科       广州通达汽车电气股份有限公司
# 7028        本科       广州瀚信通信科技股份有限公司
# 7029        本科         广东雅达电子股份有限公司
# 7030        本科       广州华友明康光电科技有限公司
# 7031        本科         广州邦讯信息系统有限公司
# 7032        本科       广州市捷胜自动化工程有限公司
# 7033        本科           广州极飞科技有限公司
# 7034        本科       华科闪云（广东）科技有限公司
# 7035        本科  北京捷通华声科技股份有限公司广州分公司
# 7036      暂无信息         广州旗骏智控科技有限公司
# 7037        大专          广州市保伦电子有限公司
# 7038        本科        广东中兴新支点技术有限公司
# 7039      暂无信息       广州市汇研微电子技术有限公司
# 7040        大专                 手盟网络
# 7041        本科       广州江南科友科技股份有限公司
# 7042        大专       广州致讯信息科技有限责任公司
# 7043        大专     广东紫晶信息存储技术股份有限公司
# 7044      暂无信息    上海哇麦信息技术有限公司广州分公司
# 7045      暂无信息       广州市泉之韵电子科技有限公司
# 7046        本科         广州高新兴机器人有限公司
# 7047        本科       广州市金其利信息科技有限公司
# 7048        本科          广州星凯跃实业有限公司
#
#                                               com_info  \
# 0                  民营公司| 150-500人| 电子技术/半导体/集成电路 计算机软件
# 1                   民营公司| 50-150人| 计算机软件 电子技术/半导体/集成电路
# 2                       民营公司| 150-500人| 计算机软件 互联网/电子商务
# 3                       民营公司| 150-500人| 互联网/电子商务 计算机软件
# 4                                 国企| 500-1000人| 计算机软件
# 5              民营公司| 150-500人| 计算机服务(系统、数据服务、维修) 计算机软件
# 6                          民营公司| 少于50人| 计算机软件 互联网/电子商务
# 7                               民营公司| 500-1000人| 计算机软件
# 8              民营公司| 150-500人| 通信/电信运营、增值服务 通信/电信/网络设备
# 9                                 民营公司| 50-150人| 计算机软件
# 10                                   合资| 电子技术/半导体/集成电路
# 11                    民营公司| 少于50人| 电子技术/半导体/集成电路 计算机软件
# 12                             民营公司| 50-150人| 机械/设备/重工
# 13                      外资（欧美）| 150-500人| 通信/电信运营、增值服务
# 14                                     国企| 家具/家电/玩具/礼品
# 15                        民营公司| 50-150人| 电子技术/半导体/集成电路
# 16                       民营公司| 150-500人| 电子技术/半导体/集成电路
# 17                           民营公司| 50-150人| 通信/电信/网络设备
# 18                               民营公司| 150-500人| 计算机软件
# 19                 民营公司| 150-500人| 电子技术/半导体/集成电路 计算机软件
# 20            民营公司| 150-500人| 通信/电信/网络设备 电子技术/半导体/集成电路
# 21                    民营公司| 50-150人| 计算机服务(系统、数据服务、维修)
# 22                     民营公司| 150-500人| 医疗设备/器械 制药/生物工程
# 23                               民营公司| 150-500人| 计算机软件
# 24              民营公司| 50-150人| 计算机服务(系统、数据服务、维修) 计算机软件
# 25                  外资（非欧美）| 1000-5000人| 物业管理/商业中心 房地产
# 26          民营公司| 1000-5000人| 电子技术/半导体/集成电路 仪器仪表/工业自动化
# 27                                    民营公司| 少于50人| 新能源
# 28           民营公司| 1000-5000人| 计算机服务(系统、数据服务、维修) 计算机软件
# 29                 上市公司| 500-1000人| 计算机软件 通信/电信运营、增值服务
# ...                                                ...
# 7019                   外资（非欧美）| 50-150人| 电子技术/半导体/集成电路
# 7020                      民营公司| 500-1000人| 计算机软件 计算机硬件
# 7021                    民营公司| 500-1000人| 电子技术/半导体/集成电路
# 7022                    上市公司| 1000-5000人| 电气/电力/水利 新能源
# 7023                       民营公司| 少于50人| 互联网/电子商务 计算机软件
# 7024         上市公司| 1000-5000人| 计算机软件 计算机服务(系统、数据服务、维修)
# 7025                 民营公司| 50-150人| 通信/电信运营、增值服务 计算机软件
# 7026                          民营公司| 少于50人| 航天/航空 计算机软件
# 7027                 上市公司| 1000-5000人| 汽车及零配件 互联网/电子商务
# 7028          民营公司| 500-1000人| 通信/电信运营、增值服务 通信/电信/网络设备
# 7029  民营公司| 500-1000人| 电子技术/半导体/集成电路 计算机服务(系统、数据服务、维修)
# 7030              民营公司| 50-150人| 医疗设备/器械 电子技术/半导体/集成电路
# 7031               民营公司| 150-500人| 通信/电信/网络设备 电气/电力/水利
# 7032                         民营公司| 50-150人| 仪器仪表/工业自动化
# 7033                   合资| 500-1000人| 通信/电信/网络设备 计算机软件
# 7034                           民营公司| 50-150人| 互联网/电子商务
# 7035                    上市公司| 150-500人| 互联网/电子商务 计算机软件
# 7036                                民营公司| 少于50人| 计算机硬件
# 7037                     合资| 1000-5000人| 电子技术/半导体/集成电路
# 7038              国企| 50-150人| 计算机软件 计算机服务(系统、数据服务、维修)
# 7039           民营公司| 50-150人| 电子技术/半导体/集成电路 仪器仪表/工业自动化
# 7040                     民营公司| 150-500人| 网络游戏 互联网/电子商务
# 7041                             民营公司| 150-500人| 计算机软件
# 7042         民营公司| 50-150人| 计算机服务(系统、数据服务、维修) 电气/电力/水利
# 7043           民营公司| 150-500人| 计算机服务(系统、数据服务、维修) 计算机硬件
# 7044                      民营公司| 50-150人| 网络游戏 互联网/电子商务
# 7045                      民营公司| 50-150人| 电子技术/半导体/集成电路
# 7046            民营公司| 50-150人| 计算机服务(系统、数据服务、维修) 计算机硬件
# 7047                          民营公司| 少于50人| 计算机软件 计算机硬件
# 7048                            民营公司| 150-500人| 汽车及零配件
#
#                                                jpb_info
# 0     【岗位职责】：1. 负责无线路由器设备底层开发;2. 负责解决路由器平台在Linux内核方面...
# 1     岗位职责1.从事ARM嵌入式产品Linux/Android BSP移植开发及驱动开发调试工作...
# 2     岗位职责：1、负责服务器、数据库(mysqlsqlserveroracle)的安装配置管理；...
# 3     岗位职责：1.负责软件项目C++部分的开发、测试和维护工作；2.软件产品相关技术文档的编写和...
# 4     岗位职责：负责Linux服务器操作系统、内核驱动、移动终端、定制业务领域的研发工作。任职资格...
# 5     1、负责项目中各种系统环境的安装、配置、管理、优化、监控及日常运维工作；2、定期分析和检查客...
# 6     岗位职责：1、负责公司相关产品的嵌入式软件开发包括嵌入式Linux硬件驱动移植、接口通信协议...
# 7     1、负责开发、测试环境的建设、管理及日常运维；2、负责应用系统的版本管理及配置部署3、负责故...
# 8     工作职责：1、根据总体设计要求协助开展软件单元设计和开发工作包括需求分析、设计以及编码、调测...
# 9     职位信息1、本科及以上学历计算机相关专业能读懂英文文献；2、掌握QT工作机制掌握QT应用开发...
# 10    1.本科及以上学历计算机技术、软件工程等相关专业； 2.掌握C语言有较好的软件编程能力；3....
# 11    岗位职责：1.负责产品的系统软件搭建linux底层驱动的编写；2.负责软件代码实现、检查和测...
# 12    a.基本要求（入门级）：i.电子工程、自动化、计算机等相关专业本科ii.熟悉C/C++语言熟...
# 13    岗位职责：负责宽带网络网关接入产品研发包括整体设计和编码工作测试和客户支持项目工作和团队协调...
# 14    1.计算机相关专业本科以上学历； 2.熟悉Linux操作系统能熟练编写shell脚本； 3....
# 15    岗位职责：1、负责linux系统相关模块定制和裁剪、调试、驱动、追踪与分析技术问题包括性能优...
# 16    技能要求：LinuxARM3288 职位主要责任：1. 负责Linux内核驱动开发和对客户进...
# 17    岗位职责:1.负责公司产品的网络升级监控优调故障排查等运维工作；2.公司内部网络和相关办公设...
# 18    亲爱的候选人：你想接触P级项目不？你想享受甲方爸爸的主动权不？（非乙方研发项目）你想掌握大数...
# 19    岗位职责：1）海思芯片下的应用程序开发（linux）;2）B/S架构下的客户端开发；3）流媒...
# 20    任职要求：1. 计算机科学与技术 、软件工程等专业全日制本科及以上学历；2、熟练掌握C语言有...
# 21    1.负责开发部项目测试、部署工作；2.负责对公司自有产品型项目持续集成环境部署及测试跟进；3...
# 22    1、linux系统环境搭建开发板调试与功能验证。2、Linux驱动开发主要负责ARM平台的底...
# 23    1、负责公司计算机网络、内部信息系统及设施的日常维护、监控及运维服务； 2、负责公司服务器安...
# 24    1. 负责Linux系统技术支持工作现场进行故障排查、处理； 2. 故障紧急响应服务问题快速...
# 25    岗位职责：1. 独立架设Linux环境的实施工作。2、负责Linux服务器的可用性、性能优化...
# 26    岗位职责：1、负责NXP i.MX系列产品技术积累与应用；2、负责编写行业推广应用方案软件；...
# 27    工作内容：主要负责车载物联网TBox的Linux应用层软件开发。岗位要求：1.有Linux内...
# 28    岗位职责：1、负责linux操作系统维护与优化规范系统目录、日志与配置文件优化系统内核参数2...
# 29    岗位职责 1.系统上线支持：根据需求编写服务上线计划并独立完成上线实施工作。2.日常运维支持...
# ...                                                 ...
# 7019   负责或参与公司新一代智能音视频产品的软件架构设计和开发； 负责嵌入式Linux设备各类驱动...
# 7020  1.统招本科以上学历计算机/软件/通信等相关专业（2020年毕业需要接受大四全职实习提供转正...
# 7021  1.本科及以上学历计算机相关专业2年以上开发工作经验；2.精通 linux C/C++编程开...
# 7022  任职要求：1、本科以上学历3-5年工作经验；2、能使用C语言和C++语言编写LINUX  驱...
# 7023  岗位职责：1、支持千万级别并发用户的接入服务开发；2、准实时消息分发服务开发；3、海量存储服...
# 7024  1.本科及本科以上学历计算机、通信、自动化等相关专业3年以上网络通信或网络安全领域工作经验；...
# 7025  岗位职责:1、  公司系统与服务器的日常远程监控维护2、  服务器操作系统及软件的安装调试、...
# 7026  岗位职责：1、主要研究和开发高效的智能故障检测诊断、预诊断算法和设计PHM软件系统功能架构；...
# 7027  岗位职责：1、负责产品设计、编码和测试工作；2、负责项目文档和产品相关资料编写；3、负责已有...
# 7028  【岗位职责】1、 为移动公司集团短信客户提供售前技术支持主要包括与客户进行技术交流、撰写技术...
# 7029  a)本科以上学历电子/通信/计算机相关专业硕士一年以上本科三年以上开发经验；b)独立承担项目...
# 7030  1、负责医疗器械产品嵌入式平台的应用软件开发；2、负责嵌入式平台的Bootloader移植L...
# 7031  资格要求：1、本科学历计算机、通信、电子、控制或者相关专业毕业；2、精通C/C++编程具有2...
# 7032  岗位要求：任职要求：1、电子、通信及计算机相关专业本科及以上学历三年以上嵌入式软件开发工作经...
# 7033  岗位职责：负责物联网后台服务的开发、维护和性能优化（包括设备接入、开放接口）。任职要求：1....
# 7034  职位详情：1、有安防系统及工程施工或维护方面的经验熟悉监控、综合布线及自动化控制者优先2、依...
# 7035  职位描述：1.负责灵云项目的实施管理负责与关键用户的需求交流和确认工作能独立对客户需求进行提...
# 7036  岗位职责：负责公司相关产品的嵌入式软件开发包括硬件驱动、接口通信协议、应用程序等；与项目相关...
# 7037  岗位职责：1、负责基于Linux平台建立技术上的服务器运维规范；2、负责网站应用的运维、管理...
# 7038  岗位职责：1、负责处理linux操作系统问题的解决；2、能独立的对内核故障应用故障等软体故障...
# 7039  职位要求：1.数学计算机通信等相关专业毕业的本科及以上学历；2.熟悉C或C++编程语言；3....
# 7040  岗位职责：1、负责海内外运营业务平台的环境部署及维护确保平台稳定的运行；2、协助运维主管完成...
# 7041  工作职责：1、分析产品需求并进行软件设计、编码、测试等工作；2、执行项目中定制化开发工作；3...
# 7042  一、岗位职责1、参与电网GIS平台基础服务架构设计；2、参与电网GIS平台相关的Webser...
# 7043  岗位职责：开发光存储系统服务器程序负责核心模块程序编写；软件模块设计验证软件模块功能；维护现...
# 7044  岗位职责：1.linux服务器初始化网页游戏的部署、更新、合服；2.分析排除系统、数据库、网...
# 7045  1.本科及以上学历计算机相关专业2年以上音视频开发工作经验；2.精通 linux C/C++...
# 7046  工作职责:1、负责C++后台软件开发；2、负责图像相关功能软件开发；3、负责软件产品的设计、...
# 7047  岗位职责：1、负责Linux平台的应用层驱动开发及调试主要是USB/串口通信；2、负责Lin...
# 7048  1.负责Linux底层驱动软件的编写、移植和调试2.负责分析和解决底层驱动的问题3.负责优化...
#
# [7049 rows x 9 columns]

# %%
df['city'] = df['city'].str[0:2]
df.head()
# Out:
#                    name city peops experience      salary education  \
# 0              linux工程师   广州   若干人      无工作经验      6-8千/月      暂无信息
# 1          linux驱动开发工程师   广州    2人     2年工作经验    1-1.2万/月        大专
# 2  Linux运维工程师（有互联网经验优先）   广州    1人   5-7年工作经验    1-1.5万/月        大专
# 3          Linux C++工程师   广州    2人   3-4年工作经验  1.5-2.5万/月        本科
# 4      Linux系统研发工程师（广州）   广州   若干人        无要求  0.8-1.6万/月        本科
#
#           company                             com_info  \
# 0      广州登高科技有限公司  民营公司| 150-500人| 电子技术/半导体/集成电路 计算机软件
# 1   广州天嵌计算机科技有限公司   民营公司| 50-150人| 计算机软件 电子技术/半导体/集成电路
# 2  广东中建普联科技股份有限公司       民营公司| 150-500人| 计算机软件 互联网/电子商务
# 3    广东创能科技股份有限公司       民营公司| 150-500人| 互联网/电子商务 计算机软件
# 4        中标软件有限公司                 国企| 500-1000人| 计算机软件
#
#                                             jpb_info
# 0  【岗位职责】：1. 负责无线路由器设备底层开发;2. 负责解决路由器平台在Linux内核方面...
# 1  岗位职责1.从事ARM嵌入式产品Linux/Android BSP移植开发及驱动开发调试工作...
# 2  岗位职责：1、负责服务器、数据库(mysqlsqlserveroracle)的安装配置管理；...
# 3  岗位职责：1.负责软件项目C++部分的开发、测试和维护工作；2.软件产品相关技术文档的编写和...
# 4  岗位职责：负责Linux服务器操作系统、内核驱动、移动终端、定制业务领域的研发工作。任职资格...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7049 entries, 0 to 7048
# Data columns (total 9 columns):
# name          7049 non-null object
# city          7049 non-null object
# peops         7049 non-null object
# experience    7049 non-null object
# salary        7049 non-null object
# education     7049 non-null object
# company       7049 non-null object
# com_info      7049 non-null object
# jpb_info      7049 non-null object
# dtypes: object(9)
# memory usage: 495.7+ KB

# %%
df['experience'] = df['experience'].str.replace('工作经验','')
df.loc[df['experience']=='无要求','experience']= '不限'
df.loc[df['experience']=='无工作经验','experience']= '不限'
df.loc[df['experience']=='无','experience']= '不限'
# df['experience'] = df['experience'].fillna(0)
df.dtypes
df.head()
# Out:
#                    name city peops experience      salary education  \
# 0              linux工程师   广州   若干人         不限      6-8千/月      暂无信息
# 1          linux驱动开发工程师   广州    2人         2年    1-1.2万/月        大专
# 2  Linux运维工程师（有互联网经验优先）   广州    1人       5-7年    1-1.5万/月        大专
# 3          Linux C++工程师   广州    2人       3-4年  1.5-2.5万/月        本科
# 4      Linux系统研发工程师（广州）   广州   若干人         不限  0.8-1.6万/月        本科
#
#           company                             com_info  \
# 0      广州登高科技有限公司  民营公司| 150-500人| 电子技术/半导体/集成电路 计算机软件
# 1   广州天嵌计算机科技有限公司   民营公司| 50-150人| 计算机软件 电子技术/半导体/集成电路
# 2  广东中建普联科技股份有限公司       民营公司| 150-500人| 计算机软件 互联网/电子商务
# 3    广东创能科技股份有限公司       民营公司| 150-500人| 互联网/电子商务 计算机软件
# 4        中标软件有限公司                 国企| 500-1000人| 计算机软件
#
#                                             jpb_info
# 0  【岗位职责】：1. 负责无线路由器设备底层开发;2. 负责解决路由器平台在Linux内核方面...
# 1  岗位职责1.从事ARM嵌入式产品Linux/Android BSP移植开发及驱动开发调试工作...
# 2  岗位职责：1、负责服务器、数据库(mysqlsqlserveroracle)的安装配置管理；...
# 3  岗位职责：1.负责软件项目C++部分的开发、测试和维护工作；2.软件产品相关技术文档的编写和...
# 4  岗位职责：负责Linux服务器操作系统、内核驱动、移动终端、定制业务领域的研发工作。任职资格...

# %%
df['com_nature'],df['com_size'],df['com_field'] = df['com_info'].str.split('|').str
del df['com_info']
df.head()
# Out:
#                    name city peops experience      salary education  \
# 0              linux工程师   广州   若干人         不限      6-8千/月      暂无信息
# 1          linux驱动开发工程师   广州    2人         2年    1-1.2万/月        大专
# 2  Linux运维工程师（有互联网经验优先）   广州    1人       5-7年    1-1.5万/月        大专
# 3          Linux C++工程师   广州    2人       3-4年  1.5-2.5万/月        本科
# 4      Linux系统研发工程师（广州）   广州   若干人         不限  0.8-1.6万/月        本科
#
#           company                                           jpb_info  \
# 0      广州登高科技有限公司  【岗位职责】：1. 负责无线路由器设备底层开发;2. 负责解决路由器平台在Linux内核方面...
# 1   广州天嵌计算机科技有限公司  岗位职责1.从事ARM嵌入式产品Linux/Android BSP移植开发及驱动开发调试工作...
# 2  广东中建普联科技股份有限公司  岗位职责：1、负责服务器、数据库(mysqlsqlserveroracle)的安装配置管理；...
# 3    广东创能科技股份有限公司  岗位职责：1.负责软件项目C++部分的开发、测试和维护工作；2.软件产品相关技术文档的编写和...
# 4        中标软件有限公司  岗位职责：负责Linux服务器操作系统、内核驱动、移动终端、定制业务领域的研发工作。任职资格...
#
#   com_nature    com_size             com_field
# 0       民营公司    150-500人   电子技术/半导体/集成电路 计算机软件
# 1       民营公司     50-150人   计算机软件 电子技术/半导体/集成电路
# 2       民营公司    150-500人        计算机软件 互联网/电子商务
# 3       民营公司    150-500人        互联网/电子商务 计算机软件
# 4         国企   500-1000人                 计算机软件

# %%
df.to_csv('result.csv')

# %%
import pandas as pd
df = pd.read_csv('re.csv',encoding='utf-8')
df['com_size'] = df['com_size'].str.replace('人','')
df
# Out:
#        无数据                          name city peops experience      salary  \
# 0        0                      linux工程师   广州   若干人         不限      6-8千/月
# 1        1                  linux驱动开发工程师   广州    2人         2年    1-1.2万/月
# 2        2          Linux运维工程师（有互联网经验优先）   广州    1人       5-7年    1-1.5万/月
# 3        3                  Linux C++工程师   广州    2人       3-4年  1.5-2.5万/月
# 4        4              Linux系统研发工程师（广州）   广州   若干人         不限  0.8-1.6万/月
# 5        5                    Linux运维工程师   广州    2人         2年    0.6-1万/月
# 6        6                 嵌入式Linux软件工程师   广州    1人       3-4年  0.8-1.1万/月
# 7        7                    Linux运维工程师   广州    3人         1年    0.8-1万/月
# 8        8      C++ / 嵌入式Linux / QT开发工程师   广州   若干人         不限      250元/天
# 9        9             Linux嵌入式软件QT开发工程师   广州    2人         2年  0.6-1.5万/月
# 10      10             软件工程师（RTOS/Linux）   广州   若干人         不限        暂无信息
# 11      11                     linux软件开发   广州    2人         不限      1-3万/月
# 12      12                  Linux嵌入开发工程师   广州    2人         1年  0.6-1.5万/月
# 13      13           Linux C软件研发工程师（BNG）   广州   若干人         不限      1-2万/月
# 14      14  TV 研发工程师-LINUX方向(000443)（广州）   广州    2人         不限        暂无信息
# 15      15                  Linux系统软件工程师   广州    1人         2年  1.4-1.7万/月
# 16      16                    Linux驱动工程师   广州    2人         不限    0.8-2万/月
# 17      17                    Linux运维工程师   广州    3人         不限      6-8千/月
# 18      18          项目经理（云平台Linux）（南方电网）   广州   若干人       5-7年      1-2万/月
# 19      19                高级linux软件开发工程师   广州    1人       3-4年  1.2-1.8万/月
# 20      20            软件工程师（Linux系统 C语言）   广州   若干人         不限  0.6-1.2万/月
# 21      21             C++中级软件工程师（Linux）   广州    1人         1年    5-7.5千/月
# 22      22                 嵌入式linux开发工程师   广州    1人         不限  1.5-2.5万/月
# 23      23                    Linux运维工程师   广州    3人       5-7年    1-1.5万/月
# 24      24                    Linux运维工程师   北京    2人         2年     8-10万/年
# 25      25                    Linux运维工程师   广州   若干人         2年    1-1.2万/月
# 26      26                  软件工程师（Linux）   广州    1人         2年  0.8-1.2万/月
# 27      27               嵌入式Linux软件开发工程师   广州    2人         2年    1-1.5万/月
# 28      28                  Linux系统运维工程师   广州   若干人       3-4年  0.8-1.2万/月
# 29      29               系统运维工程师/linux运维   广州    1人         2年      5-8千/月
# ...    ...                           ...  ...   ...        ...         ...
# 7019  7019                 嵌入式Linux开发工程师   东莞    2人         2年  0.8-2.5万/月
# 7020  7020          软件研发工程师（C/C++、linux）   广州    5人         1年    12-24万/年
# 7021  7021                    Linux开发工程师   广州    5人         2年    1-1.8万/月
# 7022  7022                    Linux开发工程师   东莞    1人       3-4年    1-1.5万/月
# 7023  7023                Linux C++高级工程师   深圳    2人       5-7年    1.5-3万/月
# 7024  7024                  linux C系统架构师   广州    2人         不限    1.5-2万/月
# 7025  7025                  linux运维工程师初级   广州    1人         2年      6-8千/月
# 7026  7026                    Linux开发工程师   广州   若干人       5-7年    25-35万/年
# 7027  7027                Linux嵌入式C++工程师   广州    1人         1年  0.8-1.3万/月
# 7028  7028                广州移动LINUX运维工程师   广州    1人         2年      5-8千/月
# 7029  7029                    Linux开发工程师   广东   若干人       3-4年  0.6-1.2万/月
# 7030  7030                 嵌入式Linux软件工程师   广州    2人       3-4年  1.3-2.5万/月
# 7031  7031               嵌入式linux系统开发工程师   广州    1人         2年  0.8-1.5万/月
# 7032  7032                 Linux嵌入式软件工程师   广州    1人       3-4年    0.8-1万/月
# 7033  7033                    Linux服务器开发   广州    1人         不限  0.8-1.6万/月
# 7034  7034                    Linux运维工程师   广州    1人         2年    1-1.5万/月
# 7035  7035                  高级Linux实施工程师   广州   若干人       3-4年    1.5-3万/月
# 7036  7036                    高级Linux工程师   广州    5人       3-4年  0.8-1.7万/月
# 7037  7037                    Linux运维工程师   广州    1人         2年    1-1.8万/月
# 7038  7038                  Linux开发运维工程师   广州   10人       3-4年  0.8-1.5万/月
# 7039  7039                    Linux开发工程师   广州    3人         不限  0.7-1.6万/月
# 7040  7040                    Linux运维工程师   广州    1人         2年    0.8-1万/月
# 7041  7041                Linux C软件开发工程师   广州    2人         不限  0.6-1.5万/月
# 7042  7042                Linux C++开发工程师   广州    1人       5-7年  0.8-1.6万/月
# 7043  7043                    Linux开发工程师   广州    2人         2年  0.8-1.5万/月
# 7044  7044                    Linux运维工程师   广州   若干人         不限    0.8-1万/月
# 7045  7045                 Linux音视频开发工程师   广州    2人         1年  0.6-1.5万/月
# 7046  7046        linux C/C++开发工程师（图像方向）   广州   若干人         1年  1.2-1.8万/月
# 7047  7047                    Linux研发工程师   广州    2人         2年    0.8-2万/月
# 7048  7048                 嵌入式linux开发工程师   广州    1人       5-7年    1-1.8万/月
#
#      education              company  \
# 0         暂无信息           广州登高科技有限公司
# 1           大专        广州天嵌计算机科技有限公司
# 2           大专       广东中建普联科技股份有限公司
# 3           本科         广东创能科技股份有限公司
# 4           本科             中标软件有限公司
# 5           大专           广东丰德科技有限公司
# 6         暂无信息         广州敦和信息技术有限公司
# 7           本科     联合永道（上海）信息技术有限公司
# 8           本科         广州智讯通信系统有限公司
# 9           本科        广州市世腾电子科技有限公司
# 10          本科      安凯（广州）微电子技术有限公司
# 11          本科         广州驰凯电子科技有限公司
# 12          本科          广州市技美机床有限公司
# 13          本科         广州凯媒通讯技术有限公司
# 14          本科              软件与服务中心
# 15          大专         广州路派电子科技有限公司
# 16        暂无信息         广东优库智联控股有限公司
# 17        暂无信息       广州市埃特斯通讯设备有限公司
# 18          本科         广州腾宇电力科技有限公司
# 19          本科         广州魅视电子科技有限公司
# 20          本科         通则康威智能科技有限公司
# 21          中专     珠海珠保金鹏安全技术服务有限公司
# 22          本科         北京华亘安邦科技有限公司
# 23          本科        广州市微柏软件股份有限公司
# 24          大专         北京神州立诚科技有限公司
# 25          大专        小高德（广州）置业有限公司
# 26          本科         广州立功科技股份有限公司
# 27          本科        浙江亿玮新能源科技有限公司
# 28          大专     上海新炬网络信息技术股份有限公司
# 29          本科                小i机器人
# ...        ...                  ...
# 7019        大专         东莞昆盈电脑制品有限公司
# 7020        本科       广州市奥威亚电子科技有限公司
# 7021        大专              迪士普研发中心
# 7022        本科          易事特集团股份有限公司
# 7023        本科         农创品牌运营股份有限公司
# 7024        本科       蓝盾信息安全技术股份有限公司
# 7025        本科         圣旺科技（广州）有限公司
# 7026        本科        广州新航行系统技术有限公司
# 7027        本科       广州通达汽车电气股份有限公司
# 7028        本科       广州瀚信通信科技股份有限公司
# 7029        本科         广东雅达电子股份有限公司
# 7030        本科       广州华友明康光电科技有限公司
# 7031        本科         广州邦讯信息系统有限公司
# 7032        本科       广州市捷胜自动化工程有限公司
# 7033        本科           广州极飞科技有限公司
# 7034        本科       华科闪云（广东）科技有限公司
# 7035        本科  北京捷通华声科技股份有限公司广州分公司
# 7036      暂无信息         广州旗骏智控科技有限公司
# 7037        大专          广州市保伦电子有限公司
# 7038        本科        广东中兴新支点技术有限公司
# 7039      暂无信息       广州市汇研微电子技术有限公司
# 7040        大专                 手盟网络
# 7041        本科       广州江南科友科技股份有限公司
# 7042        大专       广州致讯信息科技有限责任公司
# 7043        大专     广东紫晶信息存储技术股份有限公司
# 7044      暂无信息    上海哇麦信息技术有限公司广州分公司
# 7045      暂无信息       广州市泉之韵电子科技有限公司
# 7046        本科         广州高新兴机器人有限公司
# 7047        本科       广州市金其利信息科技有限公司
# 7048        本科          广州星凯跃实业有限公司
#
#                                                jpb_info com_nature  \
# 0     【岗位职责】：1. 负责无线路由器设备底层开发;2. 负责解决路由器平台在Linux内核方面...       民营公司
# 1     岗位职责1.从事ARM嵌入式产品Linux/Android BSP移植开发及驱动开发调试工作...       民营公司
# 2     岗位职责：1、负责服务器、数据库(mysqlsqlserveroracle)的安装配置管理；...       民营公司
# 3     岗位职责：1.负责软件项目C++部分的开发、测试和维护工作；2.软件产品相关技术文档的编写和...       民营公司
# 4     岗位职责：负责Linux服务器操作系统、内核驱动、移动终端、定制业务领域的研发工作。任职资格...         国企
# 5     1、负责项目中各种系统环境的安装、配置、管理、优化、监控及日常运维工作；2、定期分析和检查客...       民营公司
# 6     岗位职责：1、负责公司相关产品的嵌入式软件开发包括嵌入式Linux硬件驱动移植、接口通信协议...       民营公司
# 7     1、负责开发、测试环境的建设、管理及日常运维；2、负责应用系统的版本管理及配置部署3、负责故...       民营公司
# 8     工作职责：1、根据总体设计要求协助开展软件单元设计和开发工作包括需求分析、设计以及编码、调测...       民营公司
# 9     职位信息1、本科及以上学历计算机相关专业能读懂英文文献；2、掌握QT工作机制掌握QT应用开发...       民营公司
# 10    1.本科及以上学历计算机技术、软件工程等相关专业； 2.掌握C语言有较好的软件编程能力；3....         合资
# 11    岗位职责：1.负责产品的系统软件搭建linux底层驱动的编写；2.负责软件代码实现、检查和测...       民营公司
# 12    a.基本要求（入门级）：i.电子工程、自动化、计算机等相关专业本科ii.熟悉C/C++语言熟...       民营公司
# 13    岗位职责：负责宽带网络网关接入产品研发包括整体设计和编码工作测试和客户支持项目工作和团队协调...     外资（欧美）
# 14    1.计算机相关专业本科以上学历； 2.熟悉Linux操作系统能熟练编写shell脚本； 3....         国企
# 15    岗位职责：1、负责linux系统相关模块定制和裁剪、调试、驱动、追踪与分析技术问题包括性能优...       民营公司
# 16    技能要求：LinuxARM3288 职位主要责任：1. 负责Linux内核驱动开发和对客户进...       民营公司
# 17    岗位职责:1.负责公司产品的网络升级监控优调故障排查等运维工作；2.公司内部网络和相关办公设...       民营公司
# 18    亲爱的候选人：你想接触P级项目不？你想享受甲方爸爸的主动权不？（非乙方研发项目）你想掌握大数...       民营公司
# 19    岗位职责：1）海思芯片下的应用程序开发（linux）;2）B/S架构下的客户端开发；3）流媒...       民营公司
# 20    任职要求：1. 计算机科学与技术 、软件工程等专业全日制本科及以上学历；2、熟练掌握C语言有...       民营公司
# 21    1.负责开发部项目测试、部署工作；2.负责对公司自有产品型项目持续集成环境部署及测试跟进；3...       民营公司
# 22    1、linux系统环境搭建开发板调试与功能验证。2、Linux驱动开发主要负责ARM平台的底...       民营公司
# 23    1、负责公司计算机网络、内部信息系统及设施的日常维护、监控及运维服务； 2、负责公司服务器安...       民营公司
# 24    1. 负责Linux系统技术支持工作现场进行故障排查、处理； 2. 故障紧急响应服务问题快速...       民营公司
# 25    岗位职责：1. 独立架设Linux环境的实施工作。2、负责Linux服务器的可用性、性能优化...    外资（非欧美）
# 26    岗位职责：1、负责NXP i.MX系列产品技术积累与应用；2、负责编写行业推广应用方案软件；...       民营公司
# 27    工作内容：主要负责车载物联网TBox的Linux应用层软件开发。岗位要求：1.有Linux内...       民营公司
# 28    岗位职责：1、负责linux操作系统维护与优化规范系统目录、日志与配置文件优化系统内核参数2...       民营公司
# 29    岗位职责 1.系统上线支持：根据需求编写服务上线计划并独立完成上线实施工作。2.日常运维支持...       上市公司
# ...                                                 ...        ...
# 7019   负责或参与公司新一代智能音视频产品的软件架构设计和开发； 负责嵌入式Linux设备各类驱动...    外资（非欧美）
# 7020  1.统招本科以上学历计算机/软件/通信等相关专业（2020年毕业需要接受大四全职实习提供转正...       民营公司
# 7021  1.本科及以上学历计算机相关专业2年以上开发工作经验；2.精通 linux C/C++编程开...       民营公司
# 7022  任职要求：1、本科以上学历3-5年工作经验；2、能使用C语言和C++语言编写LINUX  驱...       上市公司
# 7023  岗位职责：1、支持千万级别并发用户的接入服务开发；2、准实时消息分发服务开发；3、海量存储服...       民营公司
# 7024  1.本科及本科以上学历计算机、通信、自动化等相关专业3年以上网络通信或网络安全领域工作经验；...       上市公司
# 7025  岗位职责:1、  公司系统与服务器的日常远程监控维护2、  服务器操作系统及软件的安装调试、...       民营公司
# 7026  岗位职责：1、主要研究和开发高效的智能故障检测诊断、预诊断算法和设计PHM软件系统功能架构；...       民营公司
# 7027  岗位职责：1、负责产品设计、编码和测试工作；2、负责项目文档和产品相关资料编写；3、负责已有...       上市公司
# 7028  【岗位职责】1、 为移动公司集团短信客户提供售前技术支持主要包括与客户进行技术交流、撰写技术...       民营公司
# 7029  a)本科以上学历电子/通信/计算机相关专业硕士一年以上本科三年以上开发经验；b)独立承担项目...       民营公司
# 7030  1、负责医疗器械产品嵌入式平台的应用软件开发；2、负责嵌入式平台的Bootloader移植L...       民营公司
# 7031  资格要求：1、本科学历计算机、通信、电子、控制或者相关专业毕业；2、精通C/C++编程具有2...       民营公司
# 7032  岗位要求：任职要求：1、电子、通信及计算机相关专业本科及以上学历三年以上嵌入式软件开发工作经...       民营公司
# 7033  岗位职责：负责物联网后台服务的开发、维护和性能优化（包括设备接入、开放接口）。任职要求：1....         合资
# 7034  职位详情：1、有安防系统及工程施工或维护方面的经验熟悉监控、综合布线及自动化控制者优先2、依...       民营公司
# 7035  职位描述：1.负责灵云项目的实施管理负责与关键用户的需求交流和确认工作能独立对客户需求进行提...       上市公司
# 7036  岗位职责：负责公司相关产品的嵌入式软件开发包括硬件驱动、接口通信协议、应用程序等；与项目相关...       民营公司
# 7037  岗位职责：1、负责基于Linux平台建立技术上的服务器运维规范；2、负责网站应用的运维、管理...         合资
# 7038  岗位职责：1、负责处理linux操作系统问题的解决；2、能独立的对内核故障应用故障等软体故障...         国企
# 7039  职位要求：1.数学计算机通信等相关专业毕业的本科及以上学历；2.熟悉C或C++编程语言；3....       民营公司
# 7040  岗位职责：1、负责海内外运营业务平台的环境部署及维护确保平台稳定的运行；2、协助运维主管完成...       民营公司
# 7041  工作职责：1、分析产品需求并进行软件设计、编码、测试等工作；2、执行项目中定制化开发工作；3...       民营公司
# 7042  一、岗位职责1、参与电网GIS平台基础服务架构设计；2、参与电网GIS平台相关的Webser...       民营公司
# 7043  岗位职责：开发光存储系统服务器程序负责核心模块程序编写；软件模块设计验证软件模块功能；维护现...       民营公司
# 7044  岗位职责：1.linux服务器初始化网页游戏的部署、更新、合服；2.分析排除系统、数据库、网...       民营公司
# 7045  1.本科及以上学历计算机相关专业2年以上音视频开发工作经验；2.精通 linux C/C++...       民营公司
# 7046  工作职责:1、负责C++后台软件开发；2、负责图像相关功能软件开发；3、负责软件产品的设计、...       民营公司
# 7047  岗位职责：1、负责Linux平台的应用层驱动开发及调试主要是USB/串口通信；2、负责Lin...       民营公司
# 7048  1.负责Linux底层驱动软件的编写、移植和调试2.负责分析和解决底层驱动的问题3.负责优化...       民营公司
#
#         com_size                         com_field
# 0        150-500               电子技术/半导体/集成电路 计算机软件
# 1         50-150               计算机软件 电子技术/半导体/集成电路
# 2        150-500                    计算机软件 互联网/电子商务
# 3        150-500                    互联网/电子商务 计算机软件
# 4       500-1000                             计算机软件
# 5        150-500           计算机服务(系统、数据服务、维修) 计算机软件
# 6           少于50                    计算机软件 互联网/电子商务
# 7       500-1000                             计算机软件
# 8        150-500           通信/电信运营、增值服务 通信/电信/网络设备
# 9         50-150                             计算机软件
# 10           无数据                     电子技术/半导体/集成电路
# 11          少于50               电子技术/半导体/集成电路 计算机软件
# 12        50-150                          机械/设备/重工
# 13       150-500                      通信/电信运营、增值服务
# 14           无数据                       家具/家电/玩具/礼品
# 15        50-150                     电子技术/半导体/集成电路
# 16       150-500                     电子技术/半导体/集成电路
# 17        50-150                        通信/电信/网络设备
# 18       150-500                             计算机软件
# 19       150-500               电子技术/半导体/集成电路 计算机软件
# 20       150-500          通信/电信/网络设备 电子技术/半导体/集成电路
# 21        50-150                 计算机服务(系统、数据服务、维修)
# 22       150-500                   医疗设备/器械 制药/生物工程
# 23       150-500                             计算机软件
# 24        50-150           计算机服务(系统、数据服务、维修) 计算机软件
# 25     1000-5000                     物业管理/商业中心 房地产
# 26     1000-5000          电子技术/半导体/集成电路 仪器仪表/工业自动化
# 27          少于50                               新能源
# 28     1000-5000           计算机服务(系统、数据服务、维修) 计算机软件
# 29      500-1000                计算机软件 通信/电信运营、增值服务
# ...          ...                               ...
# 7019      50-150                     电子技术/半导体/集成电路
# 7020    500-1000                       计算机软件 计算机硬件
# 7021    500-1000                     电子技术/半导体/集成电路
# 7022   1000-5000                      电气/电力/水利 新能源
# 7023        少于50                    互联网/电子商务 计算机软件
# 7024   1000-5000           计算机软件 计算机服务(系统、数据服务、维修)
# 7025      50-150                通信/电信运营、增值服务 计算机软件
# 7026        少于50                       航天/航空 计算机软件
# 7027   1000-5000                   汽车及零配件 互联网/电子商务
# 7028    500-1000           通信/电信运营、增值服务 通信/电信/网络设备
# 7029    500-1000   电子技术/半导体/集成电路 计算机服务(系统、数据服务、维修)
# 7030      50-150             医疗设备/器械 电子技术/半导体/集成电路
# 7031     150-500               通信/电信/网络设备 电气/电力/水利
# 7032      50-150                        仪器仪表/工业自动化
# 7033    500-1000                  通信/电信/网络设备 计算机软件
# 7034      50-150                          互联网/电子商务
# 7035     150-500                    互联网/电子商务 计算机软件
# 7036        少于50                             计算机硬件
# 7037   1000-5000                     电子技术/半导体/集成电路
# 7038      50-150           计算机软件 计算机服务(系统、数据服务、维修)
# 7039      50-150          电子技术/半导体/集成电路 仪器仪表/工业自动化
# 7040     150-500                     网络游戏 互联网/电子商务
# 7041     150-500                             计算机软件
# 7042      50-150        计算机服务(系统、数据服务、维修) 电气/电力/水利
# 7043     150-500           计算机服务(系统、数据服务、维修) 计算机硬件
# 7044      50-150                     网络游戏 互联网/电子商务
# 7045      50-150                     电子技术/半导体/集成电路
# 7046      50-150           计算机服务(系统、数据服务、维修) 计算机硬件
# 7047        少于50                       计算机软件 计算机硬件
# 7048     150-500                            汽车及零配件
#
# [7049 rows x 12 columns]

# %% [markdown]
# # 薪酬统一处理(K/月)

# %%
import re
low_salary=[]
high_salary=[]
avg_salary = []

f_csv = df['salary']
for row in f_csv:
    if row == '暂无信息':
        low_salary.append('暂无信息')
        high_salary.append('暂无信息')
        avg_salary.append('暂无信息')
        
    elif "千/月" in row:
        low = float(re.search((r'(\d+\.?\d*)-(\d+\.?\d*)'),row).group(1))
        high = float(re.search((r'(\d+\.?\d*)-(\d+\.?\d*)'),row).group(2))
        low_salary.append(low)
        high_salary.append(high)
        avg_salary.append((low+high)/2)
        
    elif "万/月" in row:
        low = float(re.search((r'(\d+\.?\d*)-(\d+\.?\d*)'),row).group(1))
        high = float(re.search((r'(\d+\.?\d*)-(\d+\.?\d*)'),row).group(2))
        low_salary.append(low * 10)
        high_salary.append(high * 10)
        avg_salary.append((low+high)*10/2)
        
    elif "万/年" in row:
        low = float(re.search((r'(\d+\.?\d*)-(\d+\.?\d*)'),row).group(1))
        high = float(re.search((r'(\d+\.?\d*)-(\d+\.?\d*)'),row).group(2))
        low_salary.append(low / 12 * 10)
        high_salary.append(high / 12 * 10)
        avg_salary.append((low+high)*10/2)
        
    elif "/天" in row:
        low = float(re.search((r'(\d+\.?\d*).*'),row).group(1))
        low_salary.append(low * 21 / 10 )
        high_salary.append(high * 30 / 10)
        avg_salary.append((low+high)/2)
        
    elif "千以下/月" in row:
        low = float(re.search((r'(\d+\.?\d*).*'),row).group(1))
        low_salary.append(0)
        high_salary.append(low)
        avg_salary.append((low+high)/2)  
    
    elif "万以下/年" in row:
        low = float(re.search((r'(\d+\.?\d*).*'),row).group(1))
        low_salary.append(0)
        high_salary.append(low/12*10)
        avg_salary.append(low/12*10/2)  
    
    elif "万以下/月" in row:
        low = float(re.search((r'(\d+\.?\d*).*'),row).group(1))
        low_salary.append(0)
        high_salary.append(low)
        avg_salary.append((low+high)/2) 
        
df['low_salary'],df['high_salary'],df['avg_salary'] = low_salary,high_salary,avg_salary
del df['salary']
df
# Out:
#        无数据                          name city peops experience education  \
# 0        0                      linux工程师   广州   若干人         不限      暂无信息
# 1        1                  linux驱动开发工程师   广州    2人         2年        大专
# 2        2          Linux运维工程师（有互联网经验优先）   广州    1人       5-7年        大专
# 3        3                  Linux C++工程师   广州    2人       3-4年        本科
# 4        4              Linux系统研发工程师（广州）   广州   若干人         不限        本科
# 5        5                    Linux运维工程师   广州    2人         2年        大专
# 6        6                 嵌入式Linux软件工程师   广州    1人       3-4年      暂无信息
# 7        7                    Linux运维工程师   广州    3人         1年        本科
# 8        8      C++ / 嵌入式Linux / QT开发工程师   广州   若干人         不限        本科
# 9        9             Linux嵌入式软件QT开发工程师   广州    2人         2年        本科
# 10      10             软件工程师（RTOS/Linux）   广州   若干人         不限        本科
# 11      11                     linux软件开发   广州    2人         不限        本科
# 12      12                  Linux嵌入开发工程师   广州    2人         1年        本科
# 13      13           Linux C软件研发工程师（BNG）   广州   若干人         不限        本科
# 14      14  TV 研发工程师-LINUX方向(000443)（广州）   广州    2人         不限        本科
# 15      15                  Linux系统软件工程师   广州    1人         2年        大专
# 16      16                    Linux驱动工程师   广州    2人         不限      暂无信息
# 17      17                    Linux运维工程师   广州    3人         不限      暂无信息
# 18      18          项目经理（云平台Linux）（南方电网）   广州   若干人       5-7年        本科
# 19      19                高级linux软件开发工程师   广州    1人       3-4年        本科
# 20      20            软件工程师（Linux系统 C语言）   广州   若干人         不限        本科
# 21      21             C++中级软件工程师（Linux）   广州    1人         1年        中专
# 22      22                 嵌入式linux开发工程师   广州    1人         不限        本科
# 23      23                    Linux运维工程师   广州    3人       5-7年        本科
# 24      24                    Linux运维工程师   北京    2人         2年        大专
# 25      25                    Linux运维工程师   广州   若干人         2年        大专
# 26      26                  软件工程师（Linux）   广州    1人         2年        本科
# 27      27               嵌入式Linux软件开发工程师   广州    2人         2年        本科
# 28      28                  Linux系统运维工程师   广州   若干人       3-4年        大专
# 29      29               系统运维工程师/linux运维   广州    1人         2年        本科
# ...    ...                           ...  ...   ...        ...       ...
# 7019  7019                 嵌入式Linux开发工程师   东莞    2人         2年        大专
# 7020  7020          软件研发工程师（C/C++、linux）   广州    5人         1年        本科
# 7021  7021                    Linux开发工程师   广州    5人         2年        大专
# 7022  7022                    Linux开发工程师   东莞    1人       3-4年        本科
# 7023  7023                Linux C++高级工程师   深圳    2人       5-7年        本科
# 7024  7024                  linux C系统架构师   广州    2人         不限        本科
# 7025  7025                  linux运维工程师初级   广州    1人         2年        本科
# 7026  7026                    Linux开发工程师   广州   若干人       5-7年        本科
# 7027  7027                Linux嵌入式C++工程师   广州    1人         1年        本科
# 7028  7028                广州移动LINUX运维工程师   广州    1人         2年        本科
# 7029  7029                    Linux开发工程师   广东   若干人       3-4年        本科
# 7030  7030                 嵌入式Linux软件工程师   广州    2人       3-4年        本科
# 7031  7031               嵌入式linux系统开发工程师   广州    1人         2年        本科
# 7032  7032                 Linux嵌入式软件工程师   广州    1人       3-4年        本科
# 7033  7033                    Linux服务器开发   广州    1人         不限        本科
# 7034  7034                    Linux运维工程师   广州    1人         2年        本科
# 7035  7035                  高级Linux实施工程师   广州   若干人       3-4年        本科
# 7036  7036                    高级Linux工程师   广州    5人       3-4年      暂无信息
# 7037  7037                    Linux运维工程师   广州    1人         2年        大专
# 7038  7038                  Linux开发运维工程师   广州   10人       3-4年        本科
# 7039  7039                    Linux开发工程师   广州    3人         不限      暂无信息
# 7040  7040                    Linux运维工程师   广州    1人         2年        大专
# 7041  7041                Linux C软件开发工程师   广州    2人         不限        本科
# 7042  7042                Linux C++开发工程师   广州    1人       5-7年        大专
# 7043  7043                    Linux开发工程师   广州    2人         2年        大专
# 7044  7044                    Linux运维工程师   广州   若干人         不限      暂无信息
# 7045  7045                 Linux音视频开发工程师   广州    2人         1年      暂无信息
# 7046  7046        linux C/C++开发工程师（图像方向）   广州   若干人         1年        本科
# 7047  7047                    Linux研发工程师   广州    2人         2年        本科
# 7048  7048                 嵌入式linux开发工程师   广州    1人       5-7年        本科
#
#                   company                                           jpb_info  \
# 0              广州登高科技有限公司  【岗位职责】：1. 负责无线路由器设备底层开发;2. 负责解决路由器平台在Linux内核方面...
# 1           广州天嵌计算机科技有限公司  岗位职责1.从事ARM嵌入式产品Linux/Android BSP移植开发及驱动开发调试工作...
# 2          广东中建普联科技股份有限公司  岗位职责：1、负责服务器、数据库(mysqlsqlserveroracle)的安装配置管理；...
# 3            广东创能科技股份有限公司  岗位职责：1.负责软件项目C++部分的开发、测试和维护工作；2.软件产品相关技术文档的编写和...
# 4                中标软件有限公司  岗位职责：负责Linux服务器操作系统、内核驱动、移动终端、定制业务领域的研发工作。任职资格...
# 5              广东丰德科技有限公司  1、负责项目中各种系统环境的安装、配置、管理、优化、监控及日常运维工作；2、定期分析和检查客...
# 6            广州敦和信息技术有限公司  岗位职责：1、负责公司相关产品的嵌入式软件开发包括嵌入式Linux硬件驱动移植、接口通信协议...
# 7        联合永道（上海）信息技术有限公司  1、负责开发、测试环境的建设、管理及日常运维；2、负责应用系统的版本管理及配置部署3、负责故...
# 8            广州智讯通信系统有限公司  工作职责：1、根据总体设计要求协助开展软件单元设计和开发工作包括需求分析、设计以及编码、调测...
# 9           广州市世腾电子科技有限公司  职位信息1、本科及以上学历计算机相关专业能读懂英文文献；2、掌握QT工作机制掌握QT应用开发...
# 10        安凯（广州）微电子技术有限公司  1.本科及以上学历计算机技术、软件工程等相关专业； 2.掌握C语言有较好的软件编程能力；3....
# 11           广州驰凯电子科技有限公司  岗位职责：1.负责产品的系统软件搭建linux底层驱动的编写；2.负责软件代码实现、检查和测...
# 12            广州市技美机床有限公司  a.基本要求（入门级）：i.电子工程、自动化、计算机等相关专业本科ii.熟悉C/C++语言熟...
# 13           广州凯媒通讯技术有限公司  岗位职责：负责宽带网络网关接入产品研发包括整体设计和编码工作测试和客户支持项目工作和团队协调...
# 14                软件与服务中心  1.计算机相关专业本科以上学历； 2.熟悉Linux操作系统能熟练编写shell脚本； 3....
# 15           广州路派电子科技有限公司  岗位职责：1、负责linux系统相关模块定制和裁剪、调试、驱动、追踪与分析技术问题包括性能优...
# 16           广东优库智联控股有限公司  技能要求：LinuxARM3288 职位主要责任：1. 负责Linux内核驱动开发和对客户进...
# 17         广州市埃特斯通讯设备有限公司  岗位职责:1.负责公司产品的网络升级监控优调故障排查等运维工作；2.公司内部网络和相关办公设...
# 18           广州腾宇电力科技有限公司  亲爱的候选人：你想接触P级项目不？你想享受甲方爸爸的主动权不？（非乙方研发项目）你想掌握大数...
# 19           广州魅视电子科技有限公司  岗位职责：1）海思芯片下的应用程序开发（linux）;2）B/S架构下的客户端开发；3）流媒...
# 20           通则康威智能科技有限公司  任职要求：1. 计算机科学与技术 、软件工程等专业全日制本科及以上学历；2、熟练掌握C语言有...
# 21       珠海珠保金鹏安全技术服务有限公司  1.负责开发部项目测试、部署工作；2.负责对公司自有产品型项目持续集成环境部署及测试跟进；3...
# 22           北京华亘安邦科技有限公司  1、linux系统环境搭建开发板调试与功能验证。2、Linux驱动开发主要负责ARM平台的底...
# 23          广州市微柏软件股份有限公司  1、负责公司计算机网络、内部信息系统及设施的日常维护、监控及运维服务； 2、负责公司服务器安...
# 24           北京神州立诚科技有限公司  1. 负责Linux系统技术支持工作现场进行故障排查、处理； 2. 故障紧急响应服务问题快速...
# 25          小高德（广州）置业有限公司  岗位职责：1. 独立架设Linux环境的实施工作。2、负责Linux服务器的可用性、性能优化...
# 26           广州立功科技股份有限公司  岗位职责：1、负责NXP i.MX系列产品技术积累与应用；2、负责编写行业推广应用方案软件；...
# 27          浙江亿玮新能源科技有限公司  工作内容：主要负责车载物联网TBox的Linux应用层软件开发。岗位要求：1.有Linux内...
# 28       上海新炬网络信息技术股份有限公司  岗位职责：1、负责linux操作系统维护与优化规范系统目录、日志与配置文件优化系统内核参数2...
# 29                  小i机器人  岗位职责 1.系统上线支持：根据需求编写服务上线计划并独立完成上线实施工作。2.日常运维支持...
# ...                   ...                                                ...
# 7019         东莞昆盈电脑制品有限公司   负责或参与公司新一代智能音视频产品的软件架构设计和开发； 负责嵌入式Linux设备各类驱动...
# 7020       广州市奥威亚电子科技有限公司  1.统招本科以上学历计算机/软件/通信等相关专业（2020年毕业需要接受大四全职实习提供转正...
# 7021              迪士普研发中心  1.本科及以上学历计算机相关专业2年以上开发工作经验；2.精通 linux C/C++编程开...
# 7022          易事特集团股份有限公司  任职要求：1、本科以上学历3-5年工作经验；2、能使用C语言和C++语言编写LINUX  驱...
# 7023         农创品牌运营股份有限公司  岗位职责：1、支持千万级别并发用户的接入服务开发；2、准实时消息分发服务开发；3、海量存储服...
# 7024       蓝盾信息安全技术股份有限公司  1.本科及本科以上学历计算机、通信、自动化等相关专业3年以上网络通信或网络安全领域工作经验；...
# 7025         圣旺科技（广州）有限公司  岗位职责:1、  公司系统与服务器的日常远程监控维护2、  服务器操作系统及软件的安装调试、...
# 7026        广州新航行系统技术有限公司  岗位职责：1、主要研究和开发高效的智能故障检测诊断、预诊断算法和设计PHM软件系统功能架构；...
# 7027       广州通达汽车电气股份有限公司  岗位职责：1、负责产品设计、编码和测试工作；2、负责项目文档和产品相关资料编写；3、负责已有...
# 7028       广州瀚信通信科技股份有限公司  【岗位职责】1、 为移动公司集团短信客户提供售前技术支持主要包括与客户进行技术交流、撰写技术...
# 7029         广东雅达电子股份有限公司  a)本科以上学历电子/通信/计算机相关专业硕士一年以上本科三年以上开发经验；b)独立承担项目...
# 7030       广州华友明康光电科技有限公司  1、负责医疗器械产品嵌入式平台的应用软件开发；2、负责嵌入式平台的Bootloader移植L...
# 7031         广州邦讯信息系统有限公司  资格要求：1、本科学历计算机、通信、电子、控制或者相关专业毕业；2、精通C/C++编程具有2...
# 7032       广州市捷胜自动化工程有限公司  岗位要求：任职要求：1、电子、通信及计算机相关专业本科及以上学历三年以上嵌入式软件开发工作经...
# 7033           广州极飞科技有限公司  岗位职责：负责物联网后台服务的开发、维护和性能优化（包括设备接入、开放接口）。任职要求：1....
# 7034       华科闪云（广东）科技有限公司  职位详情：1、有安防系统及工程施工或维护方面的经验熟悉监控、综合布线及自动化控制者优先2、依...
# 7035  北京捷通华声科技股份有限公司广州分公司  职位描述：1.负责灵云项目的实施管理负责与关键用户的需求交流和确认工作能独立对客户需求进行提...
# 7036         广州旗骏智控科技有限公司  岗位职责：负责公司相关产品的嵌入式软件开发包括硬件驱动、接口通信协议、应用程序等；与项目相关...
# 7037          广州市保伦电子有限公司  岗位职责：1、负责基于Linux平台建立技术上的服务器运维规范；2、负责网站应用的运维、管理...
# 7038        广东中兴新支点技术有限公司  岗位职责：1、负责处理linux操作系统问题的解决；2、能独立的对内核故障应用故障等软体故障...
# 7039       广州市汇研微电子技术有限公司  职位要求：1.数学计算机通信等相关专业毕业的本科及以上学历；2.熟悉C或C++编程语言；3....
# 7040                 手盟网络  岗位职责：1、负责海内外运营业务平台的环境部署及维护确保平台稳定的运行；2、协助运维主管完成...
# 7041       广州江南科友科技股份有限公司  工作职责：1、分析产品需求并进行软件设计、编码、测试等工作；2、执行项目中定制化开发工作；3...
# 7042       广州致讯信息科技有限责任公司  一、岗位职责1、参与电网GIS平台基础服务架构设计；2、参与电网GIS平台相关的Webser...
# 7043     广东紫晶信息存储技术股份有限公司  岗位职责：开发光存储系统服务器程序负责核心模块程序编写；软件模块设计验证软件模块功能；维护现...
# 7044    上海哇麦信息技术有限公司广州分公司  岗位职责：1.linux服务器初始化网页游戏的部署、更新、合服；2.分析排除系统、数据库、网...
# 7045       广州市泉之韵电子科技有限公司  1.本科及以上学历计算机相关专业2年以上音视频开发工作经验；2.精通 linux C/C++...
# 7046         广州高新兴机器人有限公司  工作职责:1、负责C++后台软件开发；2、负责图像相关功能软件开发；3、负责软件产品的设计、...
# 7047       广州市金其利信息科技有限公司  岗位职责：1、负责Linux平台的应用层驱动开发及调试主要是USB/串口通信；2、负责Lin...
# 7048          广州星凯跃实业有限公司  1.负责Linux底层驱动软件的编写、移植和调试2.负责分析和解决底层驱动的问题3.负责优化...
#
#      com_nature    com_size                         com_field low_salary  \
# 0          民营公司     150-500               电子技术/半导体/集成电路 计算机软件          6
# 1          民营公司      50-150               计算机软件 电子技术/半导体/集成电路         10
# 2          民营公司     150-500                    计算机软件 互联网/电子商务         10
# 3          民营公司     150-500                    互联网/电子商务 计算机软件         15
# 4            国企    500-1000                             计算机软件          8
# 5          民营公司     150-500           计算机服务(系统、数据服务、维修) 计算机软件          6
# 6          民营公司        少于50                    计算机软件 互联网/电子商务          8
# 7          民营公司    500-1000                             计算机软件          8
# 8          民营公司     150-500           通信/电信运营、增值服务 通信/电信/网络设备        525
# 9          民营公司      50-150                             计算机软件          6
# 10           合资         无数据                     电子技术/半导体/集成电路       暂无信息
# 11         民营公司        少于50               电子技术/半导体/集成电路 计算机软件         10
# 12         民营公司      50-150                          机械/设备/重工          6
# 13       外资（欧美）     150-500                      通信/电信运营、增值服务         10
# 14           国企         无数据                       家具/家电/玩具/礼品       暂无信息
# 15         民营公司      50-150                     电子技术/半导体/集成电路         14
# 16         民营公司     150-500                     电子技术/半导体/集成电路          8
# 17         民营公司      50-150                        通信/电信/网络设备          6
# 18         民营公司     150-500                             计算机软件         10
# 19         民营公司     150-500               电子技术/半导体/集成电路 计算机软件         12
# 20         民营公司     150-500          通信/电信/网络设备 电子技术/半导体/集成电路          6
# 21         民营公司      50-150                 计算机服务(系统、数据服务、维修)          5
# 22         民营公司     150-500                   医疗设备/器械 制药/生物工程         15
# 23         民营公司     150-500                             计算机软件         10
# 24         民营公司      50-150           计算机服务(系统、数据服务、维修) 计算机软件    6.66667
# 25      外资（非欧美）   1000-5000                     物业管理/商业中心 房地产         10
# 26         民营公司   1000-5000          电子技术/半导体/集成电路 仪器仪表/工业自动化          8
# 27         民营公司        少于50                               新能源         10
# 28         民营公司   1000-5000           计算机服务(系统、数据服务、维修) 计算机软件          8
# 29         上市公司    500-1000                计算机软件 通信/电信运营、增值服务          5
# ...         ...         ...                               ...        ...
# 7019    外资（非欧美）      50-150                     电子技术/半导体/集成电路          8
# 7020       民营公司    500-1000                       计算机软件 计算机硬件         10
# 7021       民营公司    500-1000                     电子技术/半导体/集成电路         10
# 7022       上市公司   1000-5000                      电气/电力/水利 新能源         10
# 7023       民营公司        少于50                    互联网/电子商务 计算机软件         15
# 7024       上市公司   1000-5000           计算机软件 计算机服务(系统、数据服务、维修)         15
# 7025       民营公司      50-150                通信/电信运营、增值服务 计算机软件          6
# 7026       民营公司        少于50                       航天/航空 计算机软件    20.8333
# 7027       上市公司   1000-5000                   汽车及零配件 互联网/电子商务          8
# 7028       民营公司    500-1000           通信/电信运营、增值服务 通信/电信/网络设备          5
# 7029       民营公司    500-1000   电子技术/半导体/集成电路 计算机服务(系统、数据服务、维修)          6
# 7030       民营公司      50-150             医疗设备/器械 电子技术/半导体/集成电路         13
# 7031       民营公司     150-500               通信/电信/网络设备 电气/电力/水利          8
# 7032       民营公司      50-150                        仪器仪表/工业自动化          8
# 7033         合资    500-1000                  通信/电信/网络设备 计算机软件          8
# 7034       民营公司      50-150                          互联网/电子商务         10
# 7035       上市公司     150-500                    互联网/电子商务 计算机软件         15
# 7036       民营公司        少于50                             计算机硬件          8
# 7037         合资   1000-5000                     电子技术/半导体/集成电路         10
# 7038         国企      50-150           计算机软件 计算机服务(系统、数据服务、维修)          8
# 7039       民营公司      50-150          电子技术/半导体/集成电路 仪器仪表/工业自动化          7
# 7040       民营公司     150-500                     网络游戏 互联网/电子商务          8
# 7041       民营公司     150-500                             计算机软件          6
# 7042       民营公司      50-150        计算机服务(系统、数据服务、维修) 电气/电力/水利          8
# 7043       民营公司     150-500           计算机服务(系统、数据服务、维修) 计算机硬件          8
# 7044       民营公司      50-150                     网络游戏 互联网/电子商务          8
# 7045       民营公司      50-150                     电子技术/半导体/集成电路          6
# 7046       民营公司      50-150           计算机服务(系统、数据服务、维修) 计算机硬件         12
# 7047       民营公司        少于50                       计算机软件 计算机硬件          8
# 7048       民营公司     150-500                            汽车及零配件         10
#
#      high_salary avg_salary
# 0              8          7
# 1             12         11
# 2             15       12.5
# 3             25         20
# 4             16         12
# 5             10          8
# 6             11        9.5
# 7             10          9
# 8              3      125.5
# 9             15       10.5
# 10          暂无信息       暂无信息
# 11            30         20
# 12            15       10.5
# 13            20         15
# 14          暂无信息       暂无信息
# 15            17       15.5
# 16            20         14
# 17             8          7
# 18            20         15
# 19            18         15
# 20            12          9
# 21           7.5       6.25
# 22            25         20
# 23            15       12.5
# 24       8.33333         90
# 25            12         11
# 26            12         10
# 27            15       12.5
# 28            12         10
# 29             8        6.5
# ...          ...        ...
# 7019          25       16.5
# 7020          20        180
# 7021          18         14
# 7022          15       12.5
# 7023          30       22.5
# 7024          20       17.5
# 7025           8          7
# 7026     29.1667        300
# 7027          13       10.5
# 7028           8        6.5
# 7029          12          9
# 7030          25         19
# 7031          15       11.5
# 7032          10          9
# 7033          16         12
# 7034          15       12.5
# 7035          30       22.5
# 7036          17       12.5
# 7037          18         14
# 7038          15       11.5
# 7039          16       11.5
# 7040          10          9
# 7041          15       10.5
# 7042          16         12
# 7043          15       11.5
# 7044          10          9
# 7045          15       10.5
# 7046          18         15
# 7047          20         14
# 7048          18         14
#
# [7049 rows x 14 columns]

# %% [markdown]
# # 各城市Linux行业的需求量

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 中文乱码的处理
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

count_by_city = df.groupby(['city'])['city'].count()
ax = plt.figure(figsize=(10, 8)).add_subplot(111)
sns.barplot(count_by_city.index, count_by_city.values, alpha=0.8)
ax.set_ylim([0, 8000])
ax.set_xlabel('城市', fontsize=20)
ax.set_ylabel('职位数量', fontsize=15)
ax.set_title('各城市Linux行业的需求量', size=24)
for x, y in zip(range(50), count_by_city.values):
    ax.text(x, y, '%d'%y, ha='center', va='bottom', fontsize=16, color='b')
plt.xticks(rotation=90) #x轴标签旋转
plt.savefig('images/各城市Linux行业的需求量.png')
plt.show()

# %% [markdown]
# # 词频统计

# %%
import jieba
import matplotlib.pyplot as plt
from  wordcloud import WordCloud

content = df['jpb_info']

# 读取停用词
with open('stopwords.txt', 'r',encoding='utf-8') as fp:
        stopwords = fp.read().split('\n')

contents = ''.join([txt for txt in content if txt not in stopwords and txt !='xa0'])
wordList = jieba.cut(contents)

# 词频统计
data = {}
for word in wordList:
    if len(word)==1:
        continue
    else:data[word]=data.get(word,0)+1

# 匿名函数获取每个单词的次数项统，降序
result = list(data.items())
result.sort(key=lambda x:x[1],reverse=True) # 排序
for i in range(20):
    print(result[i])
    
# 设置词云
wordSplit = " ".join(dict(result))
# backgroud_Image = plt.imread('ivitan.png')
wc = WordCloud(
            background_color='white',# 设置背景颜色
            # mask=backgroud_Image,# 设置背景图片
            max_words=100,  # 设置最大显示的字数
            stopwords = stopwords, #设置停用词
            font_path="/usr/share/fonts/SimHei.ttf",
            # 设置中文字体，使得词云可以显示（词云默认字体是“DroidSansMono.ttf字体库”，不支持中文）
            max_font_size=50,  # 设置字体最大值
            random_state=30,  # 设置有多少种随机生成状态，即有多少种配色方案
            )
mywc = wc.generate(wordSplit)  # 生成词云

# 展示词云图
plt.imshow(mywc)
plt.axis("off")
wc.to_file('images/WordCloud.png') 
plt.show()
# Out:
# ('熟悉', 22564)
# ('开发', 17400)
# ('经验', 15724)
# ('工作', 14588)
# ('负责', 11429)
# ('能力', 11172)
# ('系统', 9996)
# ('相关', 9823)
# ('技术', 9598)
# ('优先', 8738)
# ('项目', 7695)
# ('设计', 7301)
# ('要求', 6736)
# ('以上', 6268)
# ('良好', 6034)
# ('数据库', 6026)
# ('Linux', 5925)
# ('产品', 5787)
# ('使用', 5536)
# ('测试', 5395)

# %% [markdown]
# # 工作经验要求分布

# %%
import numpy as np
import matplotlib.pyplot as plt

df['experience'] = df['experience'].apply(str.strip)
count_by_experience = df.groupby(['experience'])['experience'].count()
value_by_experience = pd.DataFrame([count_by_experience.index, count_by_experience.values], index = ['experience', 'counts']).T
sort_by_experience = value_by_experience.copy()
mappings = {'不限':1, '1年':2, '2年':3, '3-4年':4, '5-7年':5,'8-9年':6,'10年以上':7}
sort_by_experience['sortby'] = sort_by_experience['experience'].map(mappings)
sort_by_experience.sort_values(by='sortby', inplace=True)

ax6 = plt.figure(figsize=(10, 8)).add_subplot(111)
sns.barplot(np.arange(len(sort_by_experience)), sort_by_experience['counts'])
ax6.set_title('工作经验要求分布', fontsize=22)
ax6.set_xlabel('工作经验', fontsize=20)
ax6.set_ylabel('')
ax6.set_xticklabels(sort_by_experience['experience'], fontsize=18)
for x, y in zip(np.arange(len(sort_by_experience)), sort_by_experience['counts']):
    ax6.text(x, y, '%d'%y, ha='center', va='bottom', fontsize=16, color='b')

plt.savefig('images/工作经验要求分布.png')
plt.show()

# %% [markdown]
# # 数据分析岗位中各类型企业所占比例

# %%
import matplotlib
import matplotlib.pyplot as plt
CompanyNature_Count = df['com_nature'].value_counts()
#设置中文字体
font = {'family': 'SimHei'}
matplotlib.rc('font', **font)
fig = plt.figure(figsize = (8, 8))
#绘制饼图, 参数pctdistance表示饼图内部字体离中心距离, labeldistance则是label的距离, radius指饼图的半径
patches, l_text, p_text = plt.pie(
    CompanyNature_Count, autopct = '%.2f%%',
    pctdistance = 0.6,
    labels = CompanyNature_Count.index,
    labeldistance=1.1, 
    radius = 1,
    wedgeprops = {'linewidth': 1.5, 'edgecolor':'black'},# 设置饼图内外边界的属性值
)
m , n= 0.02, 0.028
for t in l_text[7: 11]:
    t.set_y(m)
    m += 0.1
for p in p_text[7: 11]:
    p.set_y(n)
    n += 0.1
plt.legend(bbox_to_anchor=(1.4, 1)) 
plt.title('岗位中各类型企业所占比例', fontsize=24)
plt.savefig('images/岗位中各类型企业所占比例.png')

# %% [markdown]
# # 岗位各公司规模总数分布

# %%
CompanySize_Count = df['com_size'].value_counts()
index, bar_width= np.arange(len(CompanySize_Count)), 0.6
fig = plt.figure(figsize = (8, 6))
plt.barh(index*(-1)+bar_width, CompanySize_Count, tick_label = CompanySize_Count.index, height = bar_width)
#添加数据标签
for x,y in enumerate(CompanySize_Count):
    plt.text(y+0.1, x*(-1)+bar_width, '%s'%y, va = 'center')

plt.title('岗位各公司规模总数分布条形图', fontsize = 24)
plt.savefig('images/岗位各公司规模总数分布条形图.png')

# %%
# df['com_fileds'] = df['com_field'].str.split('|',expand=True)[0].str.split('/',expand=True)[0]
df['com_field'].value_counts()[:15].plot(
    kind='pie',
    title='Top10行业数据',
    figsize=(10,710),
    autopct='%.2f',
)
centre_circle = plt.Circle((0,0),0.5,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.ylabel('')
plt.tight_layout()
plt.legend(bbox_to_anchor=(2, 1)) 
plt.savefig('images/Top10.png')
plt.show()

# %%
boss_data1_cross = pd.crosstab(df['com_field'],df['experience'])
boss_data1_cross.sort_values(by='3-4年',ascending=False).iloc[:10].plot(kind='bar',figsize=(20,10),rot=60)
plt.title('各行业对工作年限的要求')
plt.ylabel('需求人数',fontsize=15)
plt.savefig('images/各行业对工作年限的要求.png')
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
CompanyNature_Count = df['education'].value_counts()
#设置中文字体
font = {'family': 'SimHei'}
matplotlib.rc('font', **font)
fig = plt.figure(figsize = (8, 8))
#绘制饼图, 参数pctdistance表示饼图内部字体离中心距离, labeldistance则是label的距离, radius指饼图的半径
patches, l_text, p_text = plt.pie(
    CompanyNature_Count, 
    autopct = '%.2f%%', 
    pctdistance = 0.6,
    labels = CompanyNature_Count.index, 
    labeldistance=1.1, 
    radius = 1,
    wedgeprops = {'linewidth': 1.5, 'edgecolor':'black'},# 设置饼图内外边界的属性值
)
arrowprops=dict(arrowstyle="->",connectionstyle="arc3,rad=.2")
#labeldistance，文本的位置离远点有多远，1.1指1.1倍半径的位置
#autopct，圆里面的文本格式，%3.1f%%表示小数有三位，整数有一位的浮点数
#shadow，饼是否有阴影
#startangle，起始角度，0，表示从0开始逆时针转，为第一块。一般选择从90度开始比较好看
#pctdistance，百分比的text离圆心的距离
#patches, l_texts, p_texts，为了得到饼图的返回值，p_texts饼图内部文本的，l_texts饼图外label的文本

m , n= 0.02, 0.028
for t in l_text[7: 11]:
    t.set_y(m)
    m += 0.1
for p in p_text[7: 11]:
    p.set_y(n)
    n += 0.1
plt.legend(bbox_to_anchor=(1, 1)) 
plt.title('岗位学历要求所占比例', fontsize=24)
plt.savefig('images/岗位学历要求所占比例.png')
